# %% [markdown]
# # Рятувальний круг для Marker 🛟
# Оскільки нові версії Marker (і рушія Surya) почали вимагати Docker для інференсу через vLLM на відеокартах, вони крашаться в Google Colab.
# Тут ми встановлюємо **стабільну стару версію Marker (0.2.8)**, яка працює на чистому PyTorch без жодних докерів і чудово витягує формули.
#
# **Інструкція:**
# 1. Переконайтеся, що увімкнено T4 GPU (Runtime -> Change runtime type).
# 2. Завантажте `testyvan.pdf` зліва у файли.
# 3. Виконайте комірки.

# %%
# 1. Встановлюємо стабільну версію без Docker-мілітаризму
# !pip install uv
# !uv pip install --system marker-pdf==0.2.8

# uv автоматично підтягне сумісну версію surya-ocr (0.4.x), яка ще не вимагає докера

# %%
import os

INPUT_PDF = "testyvan.pdf"
OUTPUT_DIR = "./output"

if not os.path.exists(INPUT_PDF):
    print(f"ПОМИЛКА: Файл {INPUT_PDF} не знайдено! Завантажте його у панелі зліва.")
else:
    # Запускаємо старий добрий marker_single
    # !marker_single $INPUT_PDF $OUTPUT_DIR --max_pages 500
    
    print(f"\n\n=== ГОТОВО! ===")
    print(f"Перейдіть у папку {OUTPUT_DIR} зліва, там буде папка з вашим файлом.")
